# %%
import math as m
import linecache
from collections import deque
import csv
import zipfile
import threading
import pandas as pd
import numpy as np
import os
import json
import time
from ReadersourcingToolkit import ReadersourcingToolkit

# Scroll to the bottom for the samples section

def readersourcing(parameters : ReadersourcingToolkit):
    
    # Checking parameters for weird things
    
    if parameters.days_serialization:
        if parameters.days_number % parameters.days_serialization_threshold != 0:
            raise ValueError('days_serialization_threshold must be a divider of days_number')
        if  parameters.days_serialization_threshold < 0 or parameters.days_serialization_threshold > parameters.days_number:
            raise ValueError('this must be correct: 0 < days_serialization_threshold <= days_number')
        if parameters.current_day < 0 or parameters.current_day > parameters.days_number:
            raise ValueError('this must be correct: 0 <= current_day <= days_number')
        if parameters.days_serialization_cleaning:
            if parameters.days_cleaning_threshold < 0 or parameters.days_cleaning_threshold > parameters.days_number:
                raise ValueError('this must be correct: 0 < days_cleaning_threshold <= days_number')
    if parameters.data_shuffled:
         if parameters.current_shuffle < 0:
             raise ValueError('this must be correct: current_shuffle >= 0')
         if parameters.shuffle_amount < 0:
             raise ValueError('this must be correct: shuffle_amount >= 0')

    # Reader score must be set to a very small value otherwise there will be a division by 0
    
    epsilon = 0.000001
    
    # CSV file parsing
    
    ratings_filename = parameters.ratings_filename
    info_filename = parameters.info_filename
    authors_filename = parameters.authors_filename
    
    info = pd.read_csv(info_filename)
    paper_authors = pd.read_csv(authors_filename)
    paper_authors = paper_authors.values
    paper_ratings = pd.read_csv(info_filename)
    paper_ratings = paper_ratings.values
        
    csv_offset = 2
        
    # Initial Readersourcing setup
    
    dataset_name = info["Dataset"][0]
    papers_number = info["Paper"][0]
    readers_number = info["Reader"][0]
    ratings_number = info["Rating"][0]
    authors_number = info["Author"][0]
    papers = np.arange(papers_number)
    readers = np.arange(readers_number)
    ratings = np.arange(ratings_number)
    authors = np.arange(authors_number)
    paper_steadiness = np.zeros(papers_number)
    paper_score = np.zeros(papers_number)
    rating_goodness = np.zeros(ratings_number)
    reader_steadiness = np.zeros(readers_number)
    reader_score = np.zeros(readers_number)
    reader_score.fill(epsilon)
    author_steadiness = np.zeros(authors_number)
    author_score = np.zeros(authors_number)
    
    # Day serialization handling
    
    if parameters.days_serialization:
        ratings_number_per_day = m.floor(int(ratings_number / parameters.days_number))
        computed_days = 1
        written = False
        # cleaned = False
        
    # Data shuffling handling
    
    if parameters.data_shuffled:
        ratings_filename = "{}{}".format(parameters.dataset_shuffle_path, parameters.shuffle_filename)
    
    # Output handling
    
    result_file_paths = []
    
    # Function to retrieve the authors of a given paper
    
    def get_author(current_paper) :
        
        found_authors = []
        
        for author_index, author_entry in enumerate(paper_authors) :
            current_author = int(author_entry[0])
            written_papers = author_entry[1].split(";")
            written_papers = [int(x) for x in written_papers]
            if current_paper in written_papers :
                found_authors.append(current_author)
                
        return np.asarray(found_authors)
    
    # Function to output result to file
    
    def serialize_result(current_index, verbose, parameters):
                         
        if parameters.data_shuffled:
            result_folder_path = "{}{}".format(parameters.result_shuffle_base_path, parameters.result_shuffle_folder)
        else:
            if parameters.days_serialization:
                result_folder_path = "{}{}".format(parameters.result_days_base_path, parameters.result_day_folder)
            else:
                result_folder_path = parameters.result_folder_base_path
        
        os.makedirs(result_folder_path, exist_ok=True)
    
        # Quantities output handling
    
        dictionary = [
            {'Quantity': 'Paper Steadiness', 'Identifiers': papers.tolist(), 'Values': paper_steadiness.tolist()},
            {'Quantity': 'Paper Score', 'Identifiers': papers.tolist(), 'Values': paper_score.tolist()},
            {'Quantity': 'Reader Steadiness', 'Identifiers': readers.tolist(), 'Values': reader_steadiness.tolist()},
            {'Quantity': 'Reader Score', 'Identifiers': readers.tolist(), 'Values': reader_score.tolist()},
            {'Quantity': 'Author Steadiness', 'Identifiers': authors.tolist(), 'Values': author_steadiness.tolist()},
            {'Quantity': 'Author Score', 'Identifiers': authors.tolist(), 'Values': author_score.tolist()},
        ]
        
        result_quantities_filename = "{}{}".format(result_folder_path, parameters.result_quantities_filename)
        
        if verbose:
            print("------------------------------")
            print("PRINTING QUANTITIES TO .JSON FILE AT PATH {}".format(result_quantities_filename))
        
        with open(result_quantities_filename, 'w') as result_quantities_file:  
            json.dump(dictionary, result_quantities_file)
        result_quantities_file.close()
            
        # Rating and goodness matrix output handling
        
        rating_matrix = np.zeros((readers_number, papers_number))
        goodness_matrix = np.zeros((readers_number, papers_number))
                
        for rating_index in range(csv_offset, csv_offset + current_index):
                    
            current_entry = linecache.getline(ratings_filename, rating_index).split(",")
                                
            # Example: <1,1,2,0.8,0>
            # At Timestamp 1 Reader 1 gave to Paper 2 a Rating of 0.8
            current_timestamp = int(current_entry[0])
            current_reader = int(current_entry[1])
            current_paper = int(current_entry[2])
            current_rating = float(current_entry[3])
                
            rating_matrix[current_reader][current_paper] = current_rating
            goodness_matrix[current_reader][current_paper] = rating_goodness[current_timestamp]
        
        result_ratings_filename = "{}{}".format(result_folder_path, parameters.result_ratings_filename)
        result_goodness_filename = "{}{}".format(result_folder_path, parameters.result_goodness_filename)
        
        if verbose:
            print("PRINTING RATING MATRIX TO .CSV FILE AT PATH {}".format(result_ratings_filename))
                
        paper_ratings_dataframe = pd.read_csv(ratings_filename)
        ratings_matrix = paper_ratings_dataframe.pivot_table(index="Reader", columns="Paper", values="Score")
        ratings_matrix.fillna(0, inplace=True)
        ratings_matrix.to_csv(result_ratings_filename, sep=",", header=False, index=False)
        
        with open(result_ratings_filename, mode='w', newline='') as result_ratings_file:
            ratings_writer = csv.writer(result_ratings_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            for rating_entry in rating_matrix:
                ratings_writer.writerow(rating_entry)
        result_ratings_file.close()
            
        if verbose:
            print("PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH {}".format(result_goodness_filename))
        
        with open(result_goodness_filename, mode='w', newline='') as result_goodness_file:
            goodness_writer = csv.writer(result_goodness_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            for goodness_entry in goodness_matrix:
                goodness_writer.writerow(goodness_entry)
        result_goodness_file.close()
        
        # Info output handling
        
        result_elapsed_time = time.time() - start_time 
        
        dictionary = [{'Time': result_elapsed_time}]
        
        result_info_filename = "{}{}".format(result_folder_path, parameters.result_info_filename)
        
        if verbose:
            print("PRINTING INFO TO .JSON FILE AT PATH {}".format(result_info_filename))
            print("------------------------------")
            
        with open(result_info_filename, 'w') as result_info_file:  
            json.dump(dictionary, result_info_file)
        result_info_file.close()
        
        if parameters.result_compression:
            print("--------------------------------------")
            print("---------- COMPRESSING RESULTS ----------")
            archive_filename = "{}{}.zip".format(result_folder_path, parameters.archive_name)
            archive_file = zipfile.ZipFile(archive_filename, 'w')
            for folder, subfolders, files in os.walk(result_folder_path):
                for file in files:
                    if file.endswith('.csv') or file.endswith('.json'):
                        archive_file.write(os.path.join(folder, file), os.path.relpath(os.path.join(folder,file), result_folder_path), compress_type = zipfile.ZIP_DEFLATED)
                        thread = threading.Thread(
                            target=os.remove,
                            args=[os.path.relpath(os.path.join(folder,file))]
                        )
                        thread.daemon = True
                        thread.start()
            archive_file.close()           
            print("RESULT COMPRESSED INTO A .ZIP ARCHIVE AT PATH {}".format(archive_filename))
            print("--------------------------------------")
            
        file_paths = [result_ratings_filename, result_goodness_filename, result_quantities_filename, result_info_filename]
        
        return result_elapsed_time, file_paths
    
    # Function to clean unwanted results
    
    def clean_results(results_to_clean):
        print("--------------------------------------")
        print("---------- CLEANING RESULTS ----------")
        for file_path in results_to_clean:
            if os.path.isfile(file_path):
                print("Deleting file at path: ", file_path)
                thread = threading.Thread(
                    target=os.remove,
                    args=[file_path],
                )
                thread.daemon = True
                thread.start()       
        print("--------------------------------------")
    
    # There are many "print" that you can uncomment if you have to do some debugging
    # print("##########")
        
    start_time = time.time()
      
    for index in range(csv_offset, (ratings_number + csv_offset)):
        
        if parameters.days_serialization:
            if index % (ratings_number_per_day * computed_days) == 0:
                parameters.current_day = computed_days
                parameters.update_day()
                written = False
                cleaned = False
                if parameters.days_serialization_cleaning and computed_days % parameters.days_cleaning_threshold == 0 and not cleaned:
                     clean_results(result_file_paths)
                     result_file_paths = []
                     cleaned = True
                if computed_days % parameters.days_serialization_threshold == 0 and not written:
                    print("---------- DAY {}/{} ----------".format(parameters.current_day, parameters.days_number))
                    elapsed_time, paths = serialize_result(index, verbose=False, parameters=parameters)
                    result_file_paths = result_file_paths + paths
                    written = True
                computed_days += 1
                
        percentage = 100*index/ratings_number
        if percentage % 5 == 0:
            print("{}/{} ({}/100%)".format(int(index), ratings_number, int(percentage)))
                        
        entry = linecache.getline(ratings_filename, index).split(",")
        
        # Example: <1,1,2,0.8,0>
        # At Timestamp 1 Reader 1 gave to Paper 2 a Rating of 0.8
        timestamp = int(entry[0])
        reader = int(entry[1])
        paper = int(entry[2])
        rating = float(entry[3])
        authors_of_paper = get_author(paper)
        
        # print("---------- CURRENT ENTRY ----------")
        # print(f"TIMESTAMP {timestamp} - READER {reader} - PAPER {paper} - SCORE {rating}")
    
        # COMPUTATION START: PAPER AND READER SCORE
    
        # Saving values at time t(i)
            
        old_paper_steadiness = paper_steadiness[paper]
        old_paper_score = paper_score[paper]
        old_reader_steadiness = reader_steadiness[reader]
        old_rating_goodness = rating_goodness[timestamp]
        old_reader_score = reader_score[reader]
        
        # print("---------- PRINTING VALUES AT TIME T(I) ----------")
        # print("PAPER STEADINESS T(I) ", old_paper_steadiness)
        # print("PAPER SCORE T(I) ", old_paper_score)
        # print("READER STEADINESS T(I) ", old_paper_score)
        # print("RATING GOODNESS T(I) ", rating_goodness[timestamp])
        # print("READER SCORE T(I) ", old_reader_score)
    
        # Updating values at time t(i+1)
    
        paper_steadiness[paper] = old_paper_steadiness + old_reader_score
        paper_score[paper] = ((old_paper_steadiness * old_paper_score) + (old_reader_score * rating)) / paper_steadiness[paper]
        rating_goodness[timestamp] = (1 - (m.sqrt(abs(rating - paper_score[paper]))))
        reader_steadiness[reader] = (old_reader_steadiness + paper_steadiness[paper])
        reader_score[reader] = (((old_reader_steadiness * old_reader_score) + (paper_steadiness[paper] * rating_goodness[timestamp])) / reader_steadiness[reader])
    
        # print("---------- PRINTING VALUES AT TIME T(I+1) ----------")
        # print("PAPER STEADINESS T(I+1) ", paper_steadiness[paper])
        # print("PAPER SCORE T(I+1) ", paper_score[paper])
        # print("READER STEADINESS T(I+1) ", reader_steadiness[reader])
        # print("RATING GOODNESS T(I+1) ", rating_goodness[timestamp])
        # print("READER SCORE T(I+1) ", reader_score[reader])
    
        # COMPUTATION START: AUTHOR SCORE
    
        for author in authors_of_paper :
            # Saving values at time t(i)
    
            old_author_steadiness = author_steadiness[author]
            old_author_score = author_score[author]
    
            # Updating values at time t(i+1)7
    
            author_steadiness[author] = old_author_steadiness + old_reader_score
            author_score[author] = ((old_author_steadiness * old_author_score) + (old_reader_score * rating)) / author_steadiness[author]
    
        # COMPUTATION START: PROPAGATING CHANGES TO PREVIOUS READERS
            
        previous_ratings = []        
        with open(ratings_filename) as rating_file:
            raw_previous_ratings = deque([next(rating_file) for x in range(csv_offset, (index + csv_offset))])
            raw_previous_ratings.popleft()
        rating_file.close()
        for raw_previous_rating in raw_previous_ratings:
            splitted_raw_previous_rating = raw_previous_rating.split(",")
            if len(splitted_raw_previous_rating) > 4:
                previous_rating = splitted_raw_previous_rating[:-1]
            else: 
                previous_rating = splitted_raw_previous_rating
            previous_ratings.append(previous_rating)
        previous_ratings = np.array(previous_ratings, dtype=float)
        previous_ratings = previous_ratings[
             (previous_ratings[:,1]!=float(reader)) &
             (previous_ratings[:,2]==float(paper))
        ]            
                       
        # print(" ----- PREVIOUS PAPER RATINGS -----")
    
        for previous_index, previous_entry in enumerate(previous_ratings):
                        
            # Example: <1,1,2,0.8,0>
            # At Timestamp 1 Reader 1 gave to Paper 2 a Rating of 0.8 written by Author 0
            previous_timestamp = int(previous_entry[0])
            previous_reader = int(previous_entry[1])
            previous_paper = int(previous_entry[2])
            previous_rating = previous_entry[3]
    
            # print(f"PREVIOUS TIMESTAMP {previous_timestamp} - PREVIOUS READER {previous_reader} - PREVIOUS PAPER {previous_paper} - PREVIOUS RATING {previous_rating}")
    
            # Saving previous values at time t(i)
    
            old_previous_reader_steadiness = reader_steadiness[previous_reader]
            old_previous_reader_score = reader_score[previous_reader]
            old_previous_rating = previous_rating
            old_previous_rating_goodness = rating_goodness[previous_timestamp]
    
            # Updating previous values at time t(i+1)
    
            rating_goodness[previous_timestamp] = 1 - (m.sqrt(abs(old_previous_rating - paper_score[paper])))
            reader_steadiness[previous_reader] = (old_previous_reader_steadiness + old_reader_score)
            reader_score[previous_reader] = (
                                                (old_previous_reader_steadiness * old_previous_reader_score) -
                                                (old_paper_steadiness * old_previous_rating_goodness) +
                                                (paper_steadiness[paper] * rating_goodness[previous_timestamp])
                                            ) / reader_steadiness[previous_reader]
               
        # print(" ----- PREVIOUS PAPER RATINGS END -----")
            
        # print("---------- PRINTING FINAL VALUES AT TIME T(I+1) ----------")
        # print("PAPER STEADINESS: ", paper_steadiness)
        # print("PAPER SCORE: ", paper_score)
        # print("READER STEADINESS: ", reader_steadiness)
        # print("READER SCORE: ", reader_score)
        # print("##########")
    
    elapsed_time, result_file_paths = serialize_result(ratings_number, verbose=True, parameters=parameters)
    
    if parameters.days_serialization:
        for root, dirs, files in os.walk(parameters.result_days_base_path, topdown=False):
                for name in dirs:
                    try:
                        if len(os.listdir( os.path.join(root, name) )) == 0: #check whether the directory is empty
                            print( "Deleting empty folder: ", os.path.join(root, name) )
                            try:
                                os.rmdir( os.path.join(root, name) )
                            except:
                                pass
                    except:
                        pass
        print("--------------------------------------")
    
    print("ELAPSED TIME: ", elapsed_time)
    
    # ----- ALGORITHM ENDS HERE ----- #
    
    # Summary
    
    #print("PAPER STEADINESS:  ", paper_steadiness)
    #print("PAPER SCORE:       ", paper_score)
    #print("READER STEADINESS: ", reader_steadiness)
    #print("READER SCORE:      ", reader_score)
    #print("AUTHOR STEADINESS: ", author_steadiness)
    #print("AUTHOR SCORE:      ", author_score)

# %%
# Samples

# ------------------------------
# ---------- SAMPLE 1 ----------
# ------------------------------

seed = ReadersourcingToolkit(
   dataset_name="ground_truth_1", 
   dataset_folder_path="../data/{}/",
)
try:
   readersourcing(seed)
except ValueError as error:
     print(repr(error))
# Out:
# 3/6 (50/100%)
# 6/6 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/ground_truth_1/readersourcing/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/ground_truth_1/readersourcing/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/ground_truth_1/readersourcing/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/ground_truth_1/readersourcing/info.json
# ------------------------------
# ELAPSED TIME:  0.010499000549316406

# %%
# ------------------------------
# ---------- SAMPLE 2 ----------
# ------------------------------

seed = ReadersourcingToolkit(
   dataset_name="ground_truth_2", 
   dataset_folder_path="../data/{}/",
)
try:
   readersourcing(seed)
except ValueError as error:
     print(repr(error))
# Out:
# 3/6 (50/100%)
# 6/6 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/ground_truth_2/readersourcing/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/ground_truth_2/readersourcing/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/ground_truth_2/readersourcing/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/ground_truth_2/readersourcing/info.json
# ------------------------------
# ELAPSED TIME:  0.0175015926361084

# %%
# ------------------------------
# ---------- SAMPLE 3 ----------
# ------------------------------

seed = ReadersourcingToolkit(
    dataset_name="seed_power_law_1", 
    dataset_folder_path="../data/{}/", 
)
  
try:
    readersourcing(seed)
except ValueError as error:
     print(repr(error))
# Out:
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/info.json
# ------------------------------
# ELAPSED TIME:  3.913501024246216

# %%
# ------------------------------
# ---------- SAMPLE 4 ----------
# ------------------------------

seed = ReadersourcingToolkit(
    dataset_name="seed_power_law_1", 
    dataset_folder_path="../data/{}/", 
    data_shuffled=True, 
    current_shuffle = 0,
    shuffle_amount=100
)
  
try:
    for index_shuffle in range(seed.shuffle_amount):
        print("---------------------------------")
        print("----------- SHUFFLE {} -----------".format(index_shuffle))
        seed.update_shuffle(index_shuffle)
        readersourcing(seed)
except ValueError as error:
     print(repr(error))
# Out:
# ---------------------------------
# ----------- SHUFFLE 0 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_0/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_0/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_0/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_0/info.json
# ------------------------------
# ELAPSED TIME:  4.526898384094238
# ---------------------------------
# ----------- SHUFFLE 1 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_1/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_1/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_1/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_1/info.json
# ------------------------------
# ELAPSED TIME:  3.7539963722229004
# ---------------------------------
# ----------- SHUFFLE 2 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_2/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_2/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_2/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_2/info.json
# ------------------------------
# ELAPSED TIME:  3.5285019874572754
# ---------------------------------
# ----------- SHUFFLE 3 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_3/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_3/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_3/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_3/info.json
# ------------------------------
# ELAPSED TIME:  4.299173593521118
# ---------------------------------
# ----------- SHUFFLE 4 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_4/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_4/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_4/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_4/info.json
# ------------------------------
# ELAPSED TIME:  3.8777308464050293
# ---------------------------------
# ----------- SHUFFLE 5 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_5/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_5/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_5/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_5/info.json
# ------------------------------
# ELAPSED TIME:  4.543923377990723
# ---------------------------------
# ----------- SHUFFLE 6 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_6/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_6/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_6/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_6/info.json
# ------------------------------
# ELAPSED TIME:  3.746992826461792
# ---------------------------------
# ----------- SHUFFLE 7 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_7/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_7/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_7/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_7/info.json
# ------------------------------
# ELAPSED TIME:  3.836000442504883
# ---------------------------------
# ----------- SHUFFLE 8 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_8/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_8/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_8/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_8/info.json
# ------------------------------
# ELAPSED TIME:  3.840881586074829
# ---------------------------------
# ----------- SHUFFLE 9 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_9/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_9/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_9/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_9/info.json
# ------------------------------
# ELAPSED TIME:  4.800699710845947
# ---------------------------------
# ----------- SHUFFLE 10 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_10/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_10/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_10/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_10/info.json
# ------------------------------
# ELAPSED TIME:  3.793163776397705
# ---------------------------------
# ----------- SHUFFLE 11 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_11/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_11/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_11/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_11/info.json
# ------------------------------
# ELAPSED TIME:  3.775954008102417
# ---------------------------------
# ----------- SHUFFLE 12 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_12/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_12/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_12/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_12/info.json
# ------------------------------
# ELAPSED TIME:  4.48699688911438
# ---------------------------------
# ----------- SHUFFLE 13 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_13/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_13/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_13/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_13/info.json
# ------------------------------
# ELAPSED TIME:  4.023330926895142
# ---------------------------------
# ----------- SHUFFLE 14 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_14/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_14/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_14/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_14/info.json
# ------------------------------
# ELAPSED TIME:  3.9237542152404785
# ---------------------------------
# ----------- SHUFFLE 15 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_15/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_15/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_15/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_15/info.json
# ------------------------------
# ELAPSED TIME:  3.746999740600586
# ---------------------------------
# ----------- SHUFFLE 16 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_16/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_16/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_16/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_16/info.json
# ------------------------------
# ELAPSED TIME:  4.843997001647949
# ---------------------------------
# ----------- SHUFFLE 17 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_17/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_17/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_17/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_17/info.json
# ------------------------------
# ELAPSED TIME:  3.7719991207122803
# ---------------------------------
# ----------- SHUFFLE 18 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_18/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_18/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_18/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_18/info.json
# ------------------------------
# ELAPSED TIME:  3.5579991340637207
# ---------------------------------
# ----------- SHUFFLE 19 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_19/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_19/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_19/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_19/info.json
# ------------------------------
# ELAPSED TIME:  3.6289944648742676
# ---------------------------------
# ----------- SHUFFLE 20 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_20/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_20/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_20/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_20/info.json
# ------------------------------
# ELAPSED TIME:  4.397000312805176
# ---------------------------------
# ----------- SHUFFLE 21 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_21/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_21/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_21/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_21/info.json
# ------------------------------
# ELAPSED TIME:  4.021231174468994
# ---------------------------------
# ----------- SHUFFLE 22 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_22/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_22/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_22/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_22/info.json
# ------------------------------
# ELAPSED TIME:  4.092570781707764
# ---------------------------------
# ----------- SHUFFLE 23 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_23/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_23/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_23/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_23/info.json
# ------------------------------
# ELAPSED TIME:  3.866102933883667
# ---------------------------------
# ----------- SHUFFLE 24 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_24/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_24/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_24/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_24/info.json
# ------------------------------
# ELAPSED TIME:  4.117415189743042
# ---------------------------------
# ----------- SHUFFLE 25 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_25/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_25/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_25/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_25/info.json
# ------------------------------
# ELAPSED TIME:  3.770395040512085
# ---------------------------------
# ----------- SHUFFLE 26 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_26/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_26/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_26/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_26/info.json
# ------------------------------
# ELAPSED TIME:  3.3960020542144775
# ---------------------------------
# ----------- SHUFFLE 27 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_27/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_27/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_27/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_27/info.json
# ------------------------------
# ELAPSED TIME:  3.6535415649414062
# ---------------------------------
# ----------- SHUFFLE 28 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_28/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_28/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_28/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_28/info.json
# ------------------------------
# ELAPSED TIME:  3.9896209239959717
# ---------------------------------
# ----------- SHUFFLE 29 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_29/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_29/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_29/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_29/info.json
# ------------------------------
# ELAPSED TIME:  3.6880931854248047
# ---------------------------------
# ----------- SHUFFLE 30 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_30/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_30/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_30/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_30/info.json
# ------------------------------
# ELAPSED TIME:  3.6005020141601562
# ---------------------------------
# ----------- SHUFFLE 31 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_31/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_31/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_31/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_31/info.json
# ------------------------------
# ELAPSED TIME:  3.4809958934783936
# ---------------------------------
# ----------- SHUFFLE 32 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_32/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_32/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_32/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_32/info.json
# ------------------------------
# ELAPSED TIME:  4.60386061668396
# ---------------------------------
# ----------- SHUFFLE 33 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_33/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_33/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_33/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_33/info.json
# ------------------------------
# ELAPSED TIME:  3.6970009803771973
# ---------------------------------
# ----------- SHUFFLE 34 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_34/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_34/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_34/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_34/info.json
# ------------------------------
# ELAPSED TIME:  4.787832975387573
# ---------------------------------
# ----------- SHUFFLE 35 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_35/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_35/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_35/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_35/info.json
# ------------------------------
# ELAPSED TIME:  4.384024143218994
# ---------------------------------
# ----------- SHUFFLE 36 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_36/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_36/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_36/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_36/info.json
# ------------------------------
# ELAPSED TIME:  4.126906394958496
# ---------------------------------
# ----------- SHUFFLE 37 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_37/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_37/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_37/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_37/info.json
# ------------------------------
# ELAPSED TIME:  4.42199969291687
# ---------------------------------
# ----------- SHUFFLE 38 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_38/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_38/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_38/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_38/info.json
# ------------------------------
# ELAPSED TIME:  5.171499252319336
# ---------------------------------
# ----------- SHUFFLE 39 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_39/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_39/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_39/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_39/info.json
# ------------------------------
# ELAPSED TIME:  4.271502256393433
# ---------------------------------
# ----------- SHUFFLE 40 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_40/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_40/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_40/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_40/info.json
# ------------------------------
# ELAPSED TIME:  4.342501640319824
# ---------------------------------
# ----------- SHUFFLE 41 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_41/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_41/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_41/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_41/info.json
# ------------------------------
# ELAPSED TIME:  5.167193412780762
# ---------------------------------
# ----------- SHUFFLE 42 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_42/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_42/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_42/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_42/info.json
# ------------------------------
# ELAPSED TIME:  4.139001846313477
# ---------------------------------
# ----------- SHUFFLE 43 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_43/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_43/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_43/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_43/info.json
# ------------------------------
# ELAPSED TIME:  4.252499341964722
# ---------------------------------
# ----------- SHUFFLE 44 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_44/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_44/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_44/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_44/info.json
# ------------------------------
# ELAPSED TIME:  4.120002508163452
# ---------------------------------
# ----------- SHUFFLE 45 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_45/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_45/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_45/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_45/info.json
# ------------------------------
# ELAPSED TIME:  4.49000358581543
# ---------------------------------
# ----------- SHUFFLE 46 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_46/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_46/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_46/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_46/info.json
# ------------------------------
# ELAPSED TIME:  4.143496990203857
# ---------------------------------
# ----------- SHUFFLE 47 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_47/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_47/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_47/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_47/info.json
# ------------------------------
# ELAPSED TIME:  4.302004814147949
# ---------------------------------
# ----------- SHUFFLE 48 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_48/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_48/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_48/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_48/info.json
# ------------------------------
# ELAPSED TIME:  4.6080002784729
# ---------------------------------
# ----------- SHUFFLE 49 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_49/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_49/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_49/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_49/info.json
# ------------------------------
# ELAPSED TIME:  4.0874974727630615
# ---------------------------------
# ----------- SHUFFLE 50 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_50/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_50/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_50/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_50/info.json
# ------------------------------
# ELAPSED TIME:  4.159501314163208
# ---------------------------------
# ----------- SHUFFLE 51 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_51/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_51/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_51/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_51/info.json
# ------------------------------
# ELAPSED TIME:  5.061052083969116
# ---------------------------------
# ----------- SHUFFLE 52 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_52/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_52/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_52/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_52/info.json
# ------------------------------
# ELAPSED TIME:  3.84706974029541
# ---------------------------------
# ----------- SHUFFLE 53 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_53/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_53/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_53/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_53/info.json
# ------------------------------
# ELAPSED TIME:  3.8234965801239014
# ---------------------------------
# ----------- SHUFFLE 54 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_54/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_54/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_54/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_54/info.json
# ------------------------------
# ELAPSED TIME:  4.481827259063721
# ---------------------------------
# ----------- SHUFFLE 55 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_55/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_55/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_55/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_55/info.json
# ------------------------------
# ELAPSED TIME:  4.059843063354492
# ---------------------------------
# ----------- SHUFFLE 56 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_56/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_56/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_56/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_56/info.json
# ------------------------------
# ELAPSED TIME:  4.076764345169067
# ---------------------------------
# ----------- SHUFFLE 57 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_57/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_57/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_57/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_57/info.json
# ------------------------------
# ELAPSED TIME:  3.79498553276062
# ---------------------------------
# ----------- SHUFFLE 58 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_58/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_58/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_58/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_58/info.json
# ------------------------------
# ELAPSED TIME:  3.5800015926361084
# ---------------------------------
# ----------- SHUFFLE 59 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_59/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_59/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_59/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_59/info.json
# ------------------------------
# ELAPSED TIME:  5.0290608406066895
# ---------------------------------
# ----------- SHUFFLE 60 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_60/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_60/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_60/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_60/info.json
# ------------------------------
# ELAPSED TIME:  3.542884111404419
# ---------------------------------
# ----------- SHUFFLE 61 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_61/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_61/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_61/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_61/info.json
# ------------------------------
# ELAPSED TIME:  3.49544358253479
# ---------------------------------
# ----------- SHUFFLE 62 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_62/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_62/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_62/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_62/info.json
# ------------------------------
# ELAPSED TIME:  3.524707555770874
# ---------------------------------
# ----------- SHUFFLE 63 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_63/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_63/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_63/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_63/info.json
# ------------------------------
# ELAPSED TIME:  4.306226968765259
# ---------------------------------
# ----------- SHUFFLE 64 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_64/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_64/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_64/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_64/info.json
# ------------------------------
# ELAPSED TIME:  3.537707567214966
# ---------------------------------
# ----------- SHUFFLE 65 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_65/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_65/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_65/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_65/info.json
# ------------------------------
# ELAPSED TIME:  3.471665382385254
# ---------------------------------
# ----------- SHUFFLE 66 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_66/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_66/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_66/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_66/info.json
# ------------------------------
# ELAPSED TIME:  3.7969071865081787
# ---------------------------------
# ----------- SHUFFLE 67 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# ...
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_77/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_77/info.json
# ------------------------------
# ELAPSED TIME:  3.4244954586029053
# ---------------------------------
# ----------- SHUFFLE 78 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_78/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_78/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_78/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_78/info.json
# ------------------------------
# ELAPSED TIME:  3.4815051555633545
# ---------------------------------
# ----------- SHUFFLE 79 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_79/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_79/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_79/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_79/info.json
# ------------------------------
# ELAPSED TIME:  3.595402240753174
# ---------------------------------
# ----------- SHUFFLE 80 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_80/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_80/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_80/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_80/info.json
# ------------------------------
# ELAPSED TIME:  3.329498767852783
# ---------------------------------
# ----------- SHUFFLE 81 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_81/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_81/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_81/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_81/info.json
# ------------------------------
# ELAPSED TIME:  3.3869314193725586
# ---------------------------------
# ----------- SHUFFLE 82 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_82/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_82/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_82/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_82/info.json
# ------------------------------
# ELAPSED TIME:  3.8005003929138184
# ---------------------------------
# ----------- SHUFFLE 83 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_83/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_83/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_83/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_83/info.json
# ------------------------------
# ELAPSED TIME:  3.3664963245391846
# ---------------------------------
# ----------- SHUFFLE 84 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_84/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_84/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_84/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_84/info.json
# ------------------------------
# ELAPSED TIME:  3.306002616882324
# ---------------------------------
# ----------- SHUFFLE 85 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_85/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_85/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_85/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_85/info.json
# ------------------------------
# ELAPSED TIME:  3.3394994735717773
# ---------------------------------
# ----------- SHUFFLE 86 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_86/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_86/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_86/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_86/info.json
# ------------------------------
# ELAPSED TIME:  3.3689961433410645
# ---------------------------------
# ----------- SHUFFLE 87 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_87/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_87/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_87/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_87/info.json
# ------------------------------
# ELAPSED TIME:  3.3755006790161133
# ---------------------------------
# ----------- SHUFFLE 88 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_88/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_88/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_88/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_88/info.json
# ------------------------------
# ELAPSED TIME:  3.364497661590576
# ---------------------------------
# ----------- SHUFFLE 89 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_89/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_89/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_89/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_89/info.json
# ------------------------------
# ELAPSED TIME:  3.5440030097961426
# ---------------------------------
# ----------- SHUFFLE 90 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_90/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_90/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_90/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_90/info.json
# ------------------------------
# ELAPSED TIME:  3.967000722885132
# ---------------------------------
# ----------- SHUFFLE 91 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_91/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_91/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_91/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_91/info.json
# ------------------------------
# ELAPSED TIME:  3.391497850418091
# ---------------------------------
# ----------- SHUFFLE 92 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_92/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_92/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_92/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_92/info.json
# ------------------------------
# ELAPSED TIME:  3.4475018978118896
# ---------------------------------
# ----------- SHUFFLE 93 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_93/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_93/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_93/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_93/info.json
# ------------------------------
# ELAPSED TIME:  3.453998327255249
# ---------------------------------
# ----------- SHUFFLE 94 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_94/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_94/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_94/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_94/info.json
# ------------------------------
# ELAPSED TIME:  3.4129998683929443
# ---------------------------------
# ----------- SHUFFLE 95 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_95/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_95/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_95/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_95/info.json
# ------------------------------
# ELAPSED TIME:  3.307499885559082
# ---------------------------------
# ----------- SHUFFLE 96 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_96/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_96/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_96/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_96/info.json
# ------------------------------
# ELAPSED TIME:  3.3635005950927734
# ---------------------------------
# ----------- SHUFFLE 97 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_97/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_97/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_97/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_97/info.json
# ------------------------------
# ELAPSED TIME:  3.365997791290283
# ---------------------------------
# ----------- SHUFFLE 98 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_98/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_98/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_98/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_98/info.json
# ------------------------------
# ELAPSED TIME:  3.3289976119995117
# ---------------------------------
# ----------- SHUFFLE 99 -----------
# 462/1848 (25/100%)
# 924/1848 (50/100%)
# 1386/1848 (75/100%)
# 1848/1848 (100/100%)
# ------------------------------
# PRINTING QUANTITIES TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_99/quantities.json
# PRINTING RATING MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_99/ratings.csv
# PRINTING RATING GOODNESS MATRIX TO .CSV FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_99/goodness.csv
# PRINTING INFO TO .JSON FILE AT PATH ../models/seed_power_law_1/readersourcing/shuffle/shuffle_99/info.json
# ------------------------------
# ELAPSED TIME:  3.507005214691162

# %%
# ------------------------------
# ---------- SAMPLE 5 ----------
# ------------------------------

seed = ReadersourcingToolkit(
    dataset_name="seed_power_law_1", 
    dataset_folder_path="../data/{}/", 
    data_shuffled=True, 
    current_shuffle = 0,
    shuffle_amount=100,
    shuffle_special=True
)

try:
    for index_shuffle in range(seed.shuffle_amount):
        print("---------------------------------")
        print("----------- SHUFFLE {} -----------".format(index_shuffle))
        seed.update_shuffle(index_shuffle)
        readersourcing(seed)
except ValueError as error:
     print(repr(error))
# Out:
# ---------------------------------
# ----------- SHUFFLE 0 -----------
# 105/2100 (5/100%)
# 210/2100 (10/100%)
# 315/2100 (15/100%)
# 420/2100 (20/100%)
# 525/2100 (25/100%)
# 630/2100 (30/100%)
# 735/2100 (35/100%)
# 840/2100 (40/100%)
# 945/2100 (45/100%)
# 1050/2100 (50/100%)
# 1155/2100 (55/100%)
# 1260/2100 (60/100%)
# 1365/2100 (65/100%)
# 1470/2100 (70/100%)
# 1575/2100 (75/100%)
# 1680/2100 (80/100%)
# 1785/2100 (85/100%)
# 1890/2100 (90/100%)
# ValueError("invalid literal for int() with base 10: ''")
